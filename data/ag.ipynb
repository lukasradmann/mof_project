# %%
import pandas as pd
import pprint
from IPython.display import display

df = pd.read_csv('../data/all_MOFs_screening_data.csv')
df.head()
# Out:
#                       MOFname  CO2_uptake_P0.15bar_T298K [mmol/g]  \
# 0   str_m5_o16_o16_sra_sym.77                            5.955197
# 1   str_m5_o16_o16_sra_sym.37                            5.715251
# 2  str_m5_o13_o18_sra_sym.149                            5.524486
# 3     str_m5_o2_o18_sra_sym.4                            5.517258
# 4   str_m5_o16_o16_sra_sym.31                            5.451593
#
#    CO2_uptake_error_P0.15bar_T298K [mmol/g]  \
# 0                                  0.117622
# 1                                  0.034598
# 2                                  0.155094
# 3                                  0.084320
# 4                                  0.051989
#
#    heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]  \
# 0                                       9.223227
# 1                                       8.391884
# 2                                       8.674098
# 3                                      10.791553
# 4                                       8.711414
#
#    heat_adsorption_error_CO2_P0.15bar_T298K [kcal/mol]  \
# 0                                           0.546586
# 1                                           0.149962
# 2                                           0.753841
# 3                                           0.514052
# 4                                           0.260774
#
#    excess_CO2_uptake_P0.15bar_T298K [mmol/g]  \
# 0                                   5.955127
# 1                                   5.715251
# 2                                   5.524486
# 3                                   5.517258
# 4                                   5.451476
#
#    CO2_uptake_P0.10bar_T363K [mmol/g]  \
# 0                            0.840043
# 1                            0.901656
# 2                            0.688965
# 3                            1.881691
# 4                            0.797098
#
#    CO2_uptake_error_P0.10bar_T363K [mmol/g]  \
# 0                                  0.295803
# 1                                  0.283054
# 2                                  0.191963
# 3                                  0.166854
# 4                                  0.254966
#
#    heat_adsorption_CO2_P0.10bar_T363K [kcal/mol]  \
# 0                                       7.972884
# 1                                       8.343676
# 2                                       7.546794
# 3                                       9.246778
# 4                                       8.247735
#
#    heat_adsorption_error_CO2_P0.10bar_T363K [kcal/mol]  ...  void_fraction  \
# 0                                           5.106942    ...        0.14835
# 1                                           4.785696    ...        0.16099
# 2                                           3.803472    ...        0.17980
# 3                                           1.511943    ...        0.10245
# 4                                           4.814885    ...        0.15634
#
#    void_volume [cm^3/g]  largest_free_sphere_diameter [A]  \
# 0                0.1480                           4.61370
# 1                0.1624                           4.10210
# 2                0.1810                           4.24711
# 3                0.0922                           4.11419
# 4                0.1583                           4.37077
#
#    largest_included_sphere_along_free_sphere_path_diameter [A]  \
# 0                                            3.78047
# 1                                            3.39756
# 2                                            3.26179
# 3                                            2.93595
# 4                                            3.49681
#
#    largest_included_sphere_diameter [A]  functional_groups  metal_linker  \
# 0                               4.61370                 Pr             9
# 1                               4.10055                OMe             9
# 2                               4.24603                NO2             9
# 3                               3.63925                  H             9
# 4                               4.16451                 Et             9
#
#    organic_linker1  organic_linker2  topology
# 0               16               16       sra
# 1               16               16       sra
# 2               13               18       sra
# 3                2               18       sra
# 4               16               16       sra
#
# [5 rows x 42 columns]

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_test = train_test_split(df, test_size=0.2, random_state=42)

# X_train, y_train are the training data
# X_test, y_test are the testing data

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
train_data = TabularDataset(X_train)
sample_size = 30000
train_data = train_data.sample(n=sample_size, random_state=42)
label = 'CO2_uptake_P0.15bar_T298K [mmol/g]'
predictor = TabularPredictor(label=label).fit(train_data, time_limit=60)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241111_180704"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.13
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 24.1.0: Thu Oct 10 21:05:14 PDT 2024; root:xnu-11215.41.3~2/RELEASE_ARM64_T8103
# CPU Count:          8
# Memory Avail:       5.76 GB / 16.00 GB (36.0%)
# Disk Space Avail:   416.12 GB / 460.43 GB (90.4%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ... Time limit = 60s
# AutoGluon will save models to "AutogluonModels/ag-20241111_180704"
# Train Data Rows:    30000
# Train Data Columns: 41
# Label Column:       CO2_uptake_P0.15bar_T298K [mmol/g]
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (5.451593, 0.0, 0.5197, 0.53809)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5902.77 MB
# 	Train Data (Original)  Memory Usage: 14.52 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['MOFname']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['MOFname']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 35 | ['CO2_uptake_error_P0.15bar_T298K [mmol/g]', 'heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]', 'heat_adsorption_error_CO2_P0.15bar_T298K [kcal/mol]', 'excess_CO2_uptake_P0.15bar_T298K [mmol/g]', 'CO2_uptake_P0.10bar_T363K [mmol/g]', ...]
# 		('int', [])    :  3 | ['metal_linker', 'organic_linker1', 'organic_linker2']
# 		('object', []) :  2 | ['functional_groups', 'topology']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) :  2 | ['functional_groups', 'topology']
# 		('float', [])    : 35 | ['CO2_uptake_error_P0.15bar_T298K [mmol/g]', 'heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]', 'heat_adsorption_error_CO2_P0.15bar_T298K [kcal/mol]', 'excess_CO2_uptake_P0.15bar_T298K [mmol/g]', 'CO2_uptake_P0.10bar_T363K [mmol/g]', ...]
# 		('int', [])      :  3 | ['metal_linker', 'organic_linker1', 'organic_linker2']
# 	0.2s = Fit runtime
# 	40 features in original data used to generate 40 features in processed data.
# 	Train Data (Processed) Memory Usage: 8.78 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.18s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.08333333333333333, Train Rows: 27500, Val Rows: 2500
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 59.82s of the 59.82s of remaining time.
# 	Warning: Exception caused KNeighborsUnif to fail during training... Skipping this model.
# 		Input X contains infinity or a value too large for dtype('float32').
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/knn/knn_model.py", line 104, in _fit
#     self.model = self._fit_with_samples(X=X, y=y, model_params=params, time_limit=time_limit - (time.time() - time_start))
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/knn/knn_model.py", line 225, in _fit_with_samples
#     self.model = model_type(**model_params).fit(X_samp, y_samp)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/neighbors/_regression.py", line 227, in fit
#     return self._fit(X, y)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 475, in _fit
#     X, y = self._validate_data(
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1301, in check_X_y
#     X = check_array(
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/utils/validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/utils/validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains infinity or a value too large for dtype('float32').
# Fitting model: KNeighborsDist ... Training model for up to 58.88s of the 58.88s of remaining time.
# 	Warning: Exception caused KNeighborsDist to fail during training... Skipping this model.
# 		Input X contains infinity or a value too large for dtype('float32').
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/knn/knn_model.py", line 104, in _fit
#     self.model = self._fit_with_samples(X=X, y=y, model_params=params, time_limit=time_limit - (time.time() - time_start))
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/knn/knn_model.py", line 225, in _fit_with_samples
#     self.model = model_type(**model_params).fit(X_samp, y_samp)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/neighbors/_regression.py", line 227, in fit
#     return self._fit(X, y)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 475, in _fit
#     X, y = self._validate_data(
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1301, in check_X_y
#     X = check_array(
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/utils/validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/utils/validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains infinity or a value too large for dtype('float32').
# Fitting model: LightGBMXT ... Training model for up to 58.79s of the 58.79s of remaining time.
# [1000]	valid_set's rmse: 0.0317877
# [2000]	valid_set's rmse: 0.0308592
# [3000]	valid_set's rmse: 0.0305374
# [4000]	valid_set's rmse: 0.0304221
# [5000]	valid_set's rmse: 0.0303649
# [6000]	valid_set's rmse: 0.0303126
# [7000]	valid_set's rmse: 0.0302822
# [8000]	valid_set's rmse: 0.0302713
# [9000]	valid_set's rmse: 0.0302457
# [10000]	valid_set's rmse: 0.0302379
# 	-0.0302	 = Validation score   (-root_mean_squared_error)
# 	44.6s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 13.19s of the 13.19s of remaining time.
# 	-0.0197	 = Validation score   (-root_mean_squared_error)
# 	1.17s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE ... Training model for up to 12.01s of the 12.01s of remaining time.
# 	Warning: Exception caused RandomForestMSE to fail during training... Skipping this model.
# 		Input X contains infinity or a value too large for dtype('float32').
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1904, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1844, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/autogluon/tabular/models/rf/rf_model.py", line 195, in _fit
#     model = model.fit(X, y, sample_weight=sample_weight)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 377, in fit
#     estimator._compute_missing_values_in_feature_mask(
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/tree/_classes.py", line 222, in _compute_missing_values_in_feature_mask
#     _assert_all_finite_element_wise(X, xp=np, allow_nan=True, **common_kwargs)
#   File "/opt/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/utils/validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input X contains infinity or a value too large for dtype('float32').
# Fitting model: CatBoost ... Training model for up to 11.88s of the 11.88s of remaining time.
# 	Ran out of time, early stopping on iteration 1775.
# 	-0.0186	 = Validation score   (-root_mean_squared_error)
# 	11.91s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 59.82s of the -0.04s of remaining time.
# 	Ensemble Weights: {'CatBoost': 0.6, 'LightGBM': 0.36, 'LightGBMXT': 0.04}
# 	-0.0182	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 60.06s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 3692.1 rows/s (2500 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241111_180704")

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
# Out:
# AutoGluon infers problem type is:  regression
# AutoGluon identified the following types of features:
# ('category', []) :  2 | ['functional_groups', 'topology']
# ('float', [])    : 35 | ['CO2_uptake_error_P0.15bar_T298K [mmol/g]', 'heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]', 'heat_adsorption_error_CO2_P0.15bar_T298K [kcal/mol]', 'excess_CO2_uptake_P0.15bar_T298K [mmol/g]', 'CO2_uptake_P0.10bar_T363K [mmol/g]', ...]
# ('int', [])      :  3 | ['metal_linker', 'organic_linker1', 'organic_linker2']

# %%
test_data = TabularDataset(X_test)
y_pred_proba = predictor.predict(test_data)
y_pred_proba.head()
# Out:
# 149608    0.347763
# 22600     1.427413
# 195190    0.265588
# 120233    0.431472
# 321648    0.036144
# Name: CO2_uptake_P0.15bar_T298K [mmol/g], dtype: float32

# %%
predictor.evaluate(test_data)
# Out:
# {'root_mean_squared_error': -0.01947861587825087,
#  'mean_squared_error': -0.00037941647653244684,
#  'mean_absolute_error': -0.004138627566470189,
#  'r2': 0.9986741008089098,
#  'pearsonr': 0.9993426399981425,
#  'median_absolute_error': -0.00179974484825135}

# %%
predictor.leaderboard(test_data)
# Out:
#                  model  score_test  score_val              eval_metric  \
# 0  WeightedEnsemble_L2   -0.019479  -0.018156  root_mean_squared_error
# 1             CatBoost   -0.019726  -0.018647  root_mean_squared_error
# 2             LightGBM   -0.022781  -0.019724  root_mean_squared_error
# 3           LightGBMXT   -0.031413  -0.030236  root_mean_squared_error
#
#    pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0       16.873818       0.677115  57.680487                 0.001539
# 1        0.041263       0.005256  11.910033                 0.041263
# 2        0.077225       0.003996   1.166758                 0.077225
# 3       16.753791       0.667693  44.600446                16.753791
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.000170           0.003250            2       True
# 1                0.005256          11.910033            1       True
# 2                0.003996           1.166758            1       True
# 3                0.667693          44.600446            1       True
#
#    fit_order
# 0          4
# 1          3
# 2          2
# 3          1

# %%
predictor.feature_importance(test_data)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['MOFname']
# Computing feature importance via permutation shuffling for 40 features using 5000 rows with 5 shuffle sets...
# 	304.92s	= Expected runtime (60.98s per shuffle set)
# 	266.76s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                                     importance    stddev  \
# excess_CO2_uptake_P0.15bar_T298K [mmol/g]             0.404044  0.008309
# working_capacity_vacuum_swing [mmol/g]                0.209539  0.008230
# working_capacity_temperature_swing [mmol/g]           0.104816  0.006479
# excess_CO2_binary_uptake_P0.15bar_T298K [mmol/g]      0.023294  0.003249
# CO2_uptake_P0.10bar_T363K [mmol/g]                    0.019076  0.002740
# CO2_uptake_error_P0.15bar_T298K [mmol/g]              0.013577  0.002345
# excess_CO2_uptake_P0.70bar_T413K [mmol/g]             0.011661  0.002508
# excess_CO2_uptake_P0.10bar_T363K [mmol/g]             0.008798  0.001910
# heat_adsorption_error_CO2_P0.15bar_T298K [kcal/...    0.008759  0.001040
# CO2_uptake_P0.70bar_T413K [mmol/g]                    0.007906  0.002204
# CO2_binary_uptake_P0.15bar_T298K [mmol/g]             0.005303  0.002633
# heat_adsorption_N2_binary_P0.85bar_T298K [kcal/...    0.005034  0.001479
# heat_adsorption_error_CO2_P0.70bar_T413K [kcal/...    0.003738  0.001414
# CO2_uptake_error_P0.70bar_T413K [mmol/g]              0.002212  0.001637
# CO2_uptake_error_P0.10bar_T363K [mmol/g]              0.002125  0.001565
# N2_binary_uptake_error_P0.85bar_T298K [mmol/g]        0.002103  0.000742
# heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]         0.002086  0.002049
# void_volume [cm^3/g]                                  0.002033  0.001367
# largest_included_sphere_diameter [A]                  0.001209  0.000851
# surface_area [m^2/g]                                  0.000999  0.000582
# excess_N2_binary_uptake_P0.85bar_T298K [mmol/g]       0.000861  0.001086
# CO2/N2_selectivity                                    0.000744  0.000946
# N2_binary_uptake_P0.85bar_T298K [mmol/g]              0.000553  0.000496
# CO2_binary_uptake_error_P0.15bar_T298K [mmol/g]       0.000509  0.000220
# heat_adsorption_CO2_P0.70bar_T413K [kcal/mol]         0.000389  0.000330
# heat_adsorption_CO2_binary_P0.15bar_T298K [kcal...    0.000356  0.000425
# largest_free_sphere_diameter [A]                      0.000344  0.000517
# heat_adsorption_error_N2_binary_P0.85bar_T298K ...    0.000312  0.000230
# void_fraction                                         0.000301  0.000213
# weight [u]                                            0.000298  0.000128
# organic_linker2                                       0.000272  0.000390
# functional_groups                                     0.000231  0.000262
# heat_adsorption_error_CO2_binary_P0.15bar_T298K...    0.000216  0.000385
# largest_included_sphere_along_free_sphere_path_...    0.000195  0.000387
# heat_adsorption_error_CO2_P0.10bar_T363K [kcal/...    0.000193  0.000593
# organic_linker1                                       0.000112  0.000140
# heat_adsorption_CO2_P0.10bar_T363K [kcal/mol]         0.000101  0.000167
# volume [A^3]                                          0.000089  0.000052
# topology                                              0.000069  0.000119
# metal_linker                                          0.000065  0.000078
#
#                                                          p_value  n  p99_high  \
# excess_CO2_uptake_P0.15bar_T298K [mmol/g]           2.144743e-08  5  0.421152
# working_capacity_vacuum_swing [mmol/g]              2.850337e-07  5  0.226485
# working_capacity_temperature_swing [mmol/g]         1.743245e-06  5  0.118157
# excess_CO2_binary_uptake_P0.15bar_T298K [mmol/g]    4.426830e-05  5  0.029984
# CO2_uptake_P0.10bar_T363K [mmol/g]                  4.970342e-05  5  0.024717
# CO2_uptake_error_P0.15bar_T298K [mmol/g]            1.026864e-04  5  0.018405
# excess_CO2_uptake_P0.70bar_T413K [mmol/g]           2.415344e-04  5  0.016824
# excess_CO2_uptake_P0.10bar_T363K [mmol/g]           2.507456e-04  5  0.012732
# heat_adsorption_error_CO2_P0.15bar_T298K [kcal/...  2.337137e-05  5  0.010900
# CO2_uptake_P0.70bar_T413K [mmol/g]                  6.554098e-04  5  0.012444
# CO2_binary_uptake_P0.15bar_T298K [mmol/g]           5.397433e-03  5  0.010724
# heat_adsorption_N2_binary_P0.85bar_T298K [kcal/...  7.992502e-04  5  0.008079
# heat_adsorption_error_CO2_P0.70bar_T413K [kcal/...  2.053043e-03  5  0.006650
# CO2_uptake_error_P0.70bar_T413K [mmol/g]            1.956090e-02  5  0.005583
# CO2_uptake_error_P0.10bar_T363K [mmol/g]            1.928307e-02  5  0.005348
# N2_binary_uptake_error_P0.85bar_T298K [mmol/g]      1.584387e-03  5  0.003631
# heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]       4.259208e-02  5  0.006305
# void_volume [cm^3/g]                                1.462139e-02  5  0.004847
# largest_included_sphere_diameter [A]                1.685209e-02  5  0.002961
# surface_area [m^2/g]                                9.243204e-03  5  0.002198
# excess_N2_binary_uptake_P0.85bar_T298K [mmol/g]     7.547333e-02  5  0.003098
# CO2/N2_selectivity                                  7.684662e-02  5  0.002692
# N2_binary_uptake_P0.85bar_T298K [mmol/g]            3.357006e-02  5  0.001574
# CO2_binary_uptake_error_P0.15bar_T298K [mmol/g]     3.329347e-03  5  0.000962
# heat_adsorption_CO2_P0.70bar_T413K [kcal/mol]       2.897434e-02  5  0.001069
# heat_adsorption_CO2_binary_P0.15bar_T298K [kcal...  6.717790e-02  5  0.001232
# largest_free_sphere_diameter [A]                    1.054334e-01  5  0.001408
# heat_adsorption_error_N2_binary_P0.85bar_T298K ...  1.932361e-02  5  0.000786
# void_fraction                                       1.695874e-02  5  0.000740
# weight [u]                                          3.236795e-03  5  0.000561
# organic_linker2                                     9.717398e-02  5  0.001075
# functional_groups                                   5.967278e-02  5  0.000771
# heat_adsorption_error_CO2_binary_P0.15bar_T298K...  1.385851e-01  5  0.001009
# largest_included_sphere_along_free_sphere_path_...  1.619404e-01  5  0.000991
# heat_adsorption_error_CO2_P0.10bar_T363K [kcal/...  2.532255e-01  5  0.001414
# organic_linker1                                     7.389193e-02  5  0.000400
# heat_adsorption_CO2_P0.10bar_T363K [kcal/mol]       1.247724e-01  5  0.000445
# volume [A^3]                                        9.222388e-03  5  0.000196
# topology                                            1.307961e-01  5  0.000314
# metal_linker                                        6.829081e-02  5  0.000226
#
#                                                      p99_low
# excess_CO2_uptake_P0.15bar_T298K [mmol/g]           0.386936
# working_capacity_vacuum_swing [mmol/g]              0.192592
# working_capacity_temperature_swing [mmol/g]         0.091475
# excess_CO2_binary_uptake_P0.15bar_T298K [mmol/g]    0.016604
# CO2_uptake_P0.10bar_T363K [mmol/g]                  0.013434
# CO2_uptake_error_P0.15bar_T298K [mmol/g]            0.008748
# excess_CO2_uptake_P0.70bar_T413K [mmol/g]           0.006498
# excess_CO2_uptake_P0.10bar_T363K [mmol/g]           0.004865
# heat_adsorption_error_CO2_P0.15bar_T298K [kcal/...  0.006619
# CO2_uptake_P0.70bar_T413K [mmol/g]                  0.003368
# CO2_binary_uptake_P0.15bar_T298K [mmol/g]          -0.000119
# heat_adsorption_N2_binary_P0.85bar_T298K [kcal/...  0.001989
# heat_adsorption_error_CO2_P0.70bar_T413K [kcal/...  0.000825
# CO2_uptake_error_P0.70bar_T413K [mmol/g]           -0.001159
# CO2_uptake_error_P0.10bar_T363K [mmol/g]           -0.001098
# N2_binary_uptake_error_P0.85bar_T298K [mmol/g]      0.000576
# heat_adsorption_CO2_P0.15bar_T298K [kcal/mol]      -0.002134
# void_volume [cm^3/g]                               -0.000782
# largest_included_sphere_diameter [A]               -0.000544
# surface_area [m^2/g]                               -0.000199
# excess_N2_binary_uptake_P0.85bar_T298K [mmol/g]    -0.001376
# CO2/N2_selectivity                                 -0.001205
# N2_binary_uptake_P0.85bar_T298K [mmol/g]           -0.000468
# CO2_binary_uptake_error_P0.15bar_T298K [mmol/g]     0.000056
# heat_adsorption_CO2_P0.70bar_T413K [kcal/mol]      -0.000291
# heat_adsorption_CO2_binary_P0.15bar_T298K [kcal... -0.000520
# largest_free_sphere_diameter [A]                   -0.000720
# heat_adsorption_error_N2_binary_P0.85bar_T298K ... -0.000162
# void_fraction                                      -0.000137
# weight [u]                                          0.000035
# organic_linker2                                    -0.000531
# functional_groups                                  -0.000308
# heat_adsorption_error_CO2_binary_P0.15bar_T298K... -0.000576
# largest_included_sphere_along_free_sphere_path_... -0.000602
# heat_adsorption_error_CO2_P0.10bar_T363K [kcal/... -0.001028
# organic_linker1                                    -0.000176
# heat_adsorption_CO2_P0.10bar_T363K [kcal/mol]      -0.000243
# volume [A^3]                                       -0.000018
# topology                                           -0.000175
# metal_linker                                       -0.000096
